# %%
import torch

# Vérifier si PyTorch est installé
print(f"PyTorch version : {torch.__version__}")

# Vérifier si CUDA (GPU) est disponible
if torch.cuda.is_available():
    print("CUDA est disponible !")
    num_gpus = torch.cuda.device_count()
    print(f"Nombre de GPU détectés : {num_gpus}")
    
    # Lister chaque GPU
    for i in range(num_gpus):
        print(f"GPU {i} : {torch.cuda.get_device_name(i)}")
else:
    print("CUDA n'est pas disponible, aucun GPU détecté.")
# Out:
# PyTorch version : 2.8.0+cu128
# CUDA n'est pas disponible, aucun GPU détecté.
